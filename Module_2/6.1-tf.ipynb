# %% [markdown]
# # TensorFlow Checkpoint
#
# This assessment covers building and training a `tf.keras` `Sequential` model, then applying regularization.  The dataset comes from a ["don't overfit" Kaggle competition](https://www.kaggle.com/c/dont-overfit-ii).  There are 300 features labeled 0-299, and a binary target called "target".  There are only 250 records total, meaning this is a very small dataset to be used with a neural network.
#
# _You can assume that the dataset has already been scaled._
#
# N.B. You may get comments from keras/ternsorflow regarding your kernel and runtime. These are completely normal and are informative comments, rather than warnings.

# %%
# Run this cell without changes

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Sequential, regularizers
from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# ## 1) Prepare Data for Modeling
#
# * Using `pandas`, open the file `data.csv` as a DataFrame
# * Drop the `"id"` column, since this is a unique identifier and not a feature
# * Separate the data into `X` (a DataFrame with all columns except `"target"`) and `y` (a Series with just the `"target"` column)
# * The train-test split should work as-is once you create these variables

# %%
# Replace None with appropriate code

# Read in the data
df = pd.read_csv("data.csv")

# Drop the "id" column
df = df.drop(columns="id") 

# Separate into X and y
X = df[[col for col in df.columns if col != "target"]]
y = df["target"]

# Test/train split (set the random state to 2021) and check the X_Train shape
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2021)
df.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0     1.0 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1     0.0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2     0.0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3     1.0 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4     0.0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %%
# Run this code block without any changes

# Assert

assert type(df) == pd.DataFrame
assert type(X) == pd.DataFrame
assert type(y) == pd.Series

assert X_train.shape == (187, 300)
assert y_train.shape == (187,)

# %% [markdown]
# ## 2) Instantiate a `Sequential` Model
#
# In the cell below, create an instance of a `Sequential` model ([documentation here](https://keras.io/guides/sequential_model/)) called `dense_model` with a `name` of `"dense"` and otherwise default arguments.
#
# *In other words, create a model without any layers. We will add layers in a future step.*

# %%
# Replace None with appropriate code
dense_model = Sequential(name="dense")

# %%
# Run this code without change

# Assert

assert len(dense_model.layers) == 0
assert type(dense_model) == Sequential
assert dense_model.name == "dense"

# %% [markdown]
# ## 3) Determine Input and Output Shapes
#
# How many input and output nodes should this model have?
#
# Feel free to explore the attributes of `X` and `y` to determine this answer, or just to enter numbers based on the problem description above.

# %%
X.shape
# Out:
# (250, 300)

# %%
# Replace None with appropriate code

num_input_nodes = 300
num_output_nodes = 1

# %%
# Run this code without change

# Both values should be integers
assert type(num_input_nodes) == int
assert type(num_output_nodes) == int

score = 0

# 300 features, so 300 input nodes
if num_input_nodes == 300:
    score += 0.5
    
# binary output, so 1 output node
if num_output_nodes == 1:
    score += 0.5
elif num_output_nodes == 2:
    # Partial credit for this answer, since it's technically
    # possible to use 2 output nodes for this, although it's
    # confusingly redundant
    score += 0.25

score
# Out:
# 1.0

# %% [markdown]
# The code below will use the input and output shapes you specified to add `Dense` layers to the model:

# %%
# Run this cell without changes

# Add input layer
dense_model.add(Dense(units=64, input_shape=(num_input_nodes,)))

# Add hidden layers
dense_model.add(Dense(units=64))
dense_model.add(Dense(units=64))

dense_model.layers
# Out:
# C:\Users\anjacobs\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [<Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %% [markdown]
# ## 4) Add an Output Layer
#
# Specify an appropriate activation function ([documentation here](https://keras.io/api/layers/activations/)).
#
# We'll simplify the problem by specifying that you should use the string identifier for the function, and it should be one of these options:
#
# * `sigmoid`
# * `softmax`
#
# ***Hint:*** is this a binary or a multi-class problem? This should guide your choice of activation function.

# %%
df["target"].value_counts()
# Out:
# target
# 0.0    183
# 1.0     67
# Name: count, dtype: int64

# %%
# Replace None with appropriate code

activation_function = "sigmoid"

# %%
# Run this cell without changes

# activation_function should be a string
assert type(activation_function) == str

if num_output_nodes == 1:
    assert activation_function == "sigmoid"
else:
    # The number of output nodes _should_ be 1, but we'll
    # give credit for a matching function even if the
    # previous answer was incorrect
    assert activation_function == "softmax"

# %% [markdown]
# Now we'll use that information to finalize the model.
#
# If this code produces an error, consider restarting the kernel and re-running the code above. If it still produces an error, that is an indication that one or more of your answers above is incorrect.

# %%
# Run this cell without changes

# Add output layer
dense_model.add(Dense(units=num_output_nodes, activation=activation_function))

# Determine appropriate loss function
if num_output_nodes == 1:
    loss = "binary_crossentropy"
else:
    loss = "categorical_crossentropy"

# Compile model
dense_model.compile(
    optimizer="adam",
    loss=loss,
    metrics=["accuracy"]
)

dense_model.summary()
# Out:
# Model: "dense"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,649 (108.00 KB)
#  Trainable params: 27,649 (108.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Replace None as necessary

# Fit the model to the training data, using a subset of the
# training data as validation data
dense_model_results = dense_model.fit(
    x=X_train,
    y=y_train,
    batch_size=0,
    epochs=20,
    verbose=True,
    validation_split=0.4,
    shuffle=True
)
# Out:
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.4984 - loss: 0.9528 - val_accuracy: 0.5467 - val_loss: 0.7671
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7324 - loss: 0.5275 - val_accuracy: 0.5867 - val_loss: 0.7545
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8878 - loss: 0.3759 - val_accuracy: 0.6133 - val_loss: 0.7800
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9241 - loss: 0.2607 - val_accuracy: 0.6000 - val_loss: 0.8211
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9799 - loss: 0.1713 - val_accuracy: 0.5733 - val_loss: 0.8773
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9943 - loss: 0.1061 - val_accuracy: 0.5333 - val_loss: 0.9566
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9850 - loss: 0.0732 - val_accuracy: 0.5200 - val_loss: 1.0510
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0373 - val_accuracy: 0.5067 - val_loss: 1.1499
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 0.4933 - val_loss: 1.2490
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.4933 - val_loss: 1.3398
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.5200 - val_loss: 1.4195
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.5200 - val_loss: 1.4869
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.5200 - val_loss: 1.5433
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.5200 - val_loss: 1.5906
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.5200 - val_loss: 1.6294
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5200 - val_loss: 1.6623
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5333 - val_loss: 1.6895
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5200 - val_loss: 1.7131
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5200 - val_loss: 1.7335
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5200 - val_loss: 1.7521
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5200 - val_loss: 1.7691
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5200 - val_loss: 1.7845
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5200 - val_loss: 1.7982
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5200 - val_loss: 1.8114
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5200 - val_loss: 1.8236
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.2254e-04 - val_accuracy: 0.5200 - val_loss: 1.8353
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 9.3033e-04 - val_accuracy: 0.5200 - val_loss: 1.8465
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.7888e-04 - val_accuracy: 0.5200 - val_loss: 1.8575
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.9697e-04 - val_accuracy: 0.5200 - val_loss: 1.8682
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.7962e-04 - val_accuracy: 0.5200 - val_loss: 1.8785
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 7.0293e-04 - val_accuracy: 0.5200 - val_loss: 1.8888
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.8470e-04 - val_accuracy: 0.5200 - val_loss: 1.8988
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.9040e-04 - val_accuracy: 0.5200 - val_loss: 1.9084
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.2752e-04 - val_accuracy: 0.5200 - val_loss: 1.9179
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.1040e-04 - val_accuracy: 0.5200 - val_loss: 1.9272
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 5.9345e-04 - val_accuracy: 0.5200 - val_loss: 1.9362
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 5.4779e-04 - val_accuracy: 0.5200 - val_loss: 1.9453
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.2785e-04 - val_accuracy: 0.5200 - val_loss: 1.9539
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.2290e-04 - val_accuracy: 0.5200 - val_loss: 1.9630
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 4.8834e-04 - val_accuracy: 0.5200 - val_loss: 1.9718
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.6713e-04 - val_accuracy: 0.5200 - val_loss: 1.9806
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 4.3548e-04 - val_accuracy: 0.5200 - val_loss: 1.9891
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.4611e-04 - val_accuracy: 0.5200 - val_loss: 1.9976
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.1840e-04 - val_accuracy: 0.5200 - val_loss: 2.0057
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.2778e-04 - val_accuracy: 0.5200 - val_loss: 2.0136
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 3.7997e-04 - val_accuracy: 0.5200 - val_loss: 2.0212
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.0062e-04 - val_accuracy: 0.5200 - val_loss: 2.0288
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.1672e-04 - val_accuracy: 0.5200 - val_loss: 2.0364
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 3.5534e-04 - val_accuracy: 0.5200 - val_loss: 2.0435
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.3599e-04 - val_accuracy: 0.5200 - val_loss: 2.0505
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.3754e-04 - val_accuracy: 0.5200 - val_loss: 2.0574
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.2496e-04 - val_accuracy: 0.5200 - val_loss: 2.0639
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.2080e-04 - val_accuracy: 0.5200 - val_loss: 2.0707
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.1371e-04 - val_accuracy: 0.5200 - val_loss: 2.0773
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.0496e-04 - val_accuracy: 0.5200 - val_loss: 2.0839
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.0953e-04 - val_accuracy: 0.5200 - val_loss: 2.0906
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.8730e-04 - val_accuracy: 0.5200 - val_loss: 2.0972
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.6529e-04 - val_accuracy: 0.5200 - val_loss: 2.1038
# Epoch 59/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.6045e-04 - val_accuracy: 0.5200 - val_loss: 2.1102
# Epoch 60/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.7981e-04 - val_accuracy: 0.5200 - val_loss: 2.1166
# Epoch 61/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.4884e-04 - val_accuracy: 0.5200 - val_loss: 2.1226
# Epoch 62/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.4939e-04 - val_accuracy: 0.5200 - val_loss: 2.1285
# Epoch 63/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.4205e-04 - val_accuracy: 0.5200 - val_loss: 2.1347
# Epoch 64/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.3044e-04 - val_accuracy: 0.5200 - val_loss: 2.1407
# Epoch 65/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.3447e-04 - val_accuracy: 0.5200 - val_loss: 2.1469
# Epoch 66/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.0763e-04 - val_accuracy: 0.5200 - val_loss: 2.1530
# Epoch 67/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.9627e-04 - val_accuracy: 0.5200 - val_loss: 2.1590
# Epoch 68/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.1190e-04 - val_accuracy: 0.5200 - val_loss: 2.1650
# Epoch 69/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.1507e-04 - val_accuracy: 0.5200 - val_loss: 2.1707
# Epoch 70/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.0787e-04 - val_accuracy: 0.5200 - val_loss: 2.1765
# Epoch 71/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.7818e-04 - val_accuracy: 0.5200 - val_loss: 2.1820
# Epoch 72/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.7658e-04 - val_accuracy: 0.5200 - val_loss: 2.1878
# Epoch 73/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.8118e-04 - val_accuracy: 0.5200 - val_loss: 2.1934
# Epoch 74/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.9318e-04 - val_accuracy: 0.5200 - val_loss: 2.1988
# Epoch 75/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.7844e-04 - val_accuracy: 0.5200 - val_loss: 2.2040
# Epoch 76/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.6360e-04 - val_accuracy: 0.5200 - val_loss: 2.2090
# Epoch 77/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.7039e-04 - val_accuracy: 0.5200 - val_loss: 2.2142
# Epoch 78/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.7141e-04 - val_accuracy: 0.5200 - val_loss: 2.2193
# Epoch 79/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.6094e-04 - val_accuracy: 0.5200 - val_loss: 2.2241
# Epoch 80/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.5110e-04 - val_accuracy: 0.5200 - val_loss: 2.2291
# Epoch 81/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.5349e-04 - val_accuracy: 0.5200 - val_loss: 2.2341
# Epoch 82/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.5551e-04 - val_accuracy: 0.5200 - val_loss: 2.2389
# Epoch 83/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.5154e-04 - val_accuracy: 0.5200 - val_loss: 2.2437
# Epoch 84/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.4606e-04 - val_accuracy: 0.5200 - val_loss: 2.2482
# Epoch 85/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.3991e-04 - val_accuracy: 0.5200 - val_loss: 2.2528
# Epoch 86/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.4561e-04 - val_accuracy: 0.5200 - val_loss: 2.2574
# Epoch 87/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.3602e-04 - val_accuracy: 0.5200 - val_loss: 2.2619
# Epoch 88/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4127e-04 - val_accuracy: 0.5200 - val_loss: 2.2663
# Epoch 89/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2591e-04 - val_accuracy: 0.5200 - val_loss: 2.2707
# Epoch 90/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2741e-04 - val_accuracy: 0.5200 - val_loss: 2.2752
# Epoch 91/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1392e-04 - val_accuracy: 0.5200 - val_loss: 2.2797
# Epoch 92/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2203e-04 - val_accuracy: 0.5200 - val_loss: 2.2842
# Epoch 93/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.1783e-04 - val_accuracy: 0.5200 - val_loss: 2.2886
# Epoch 94/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.2235e-04 - val_accuracy: 0.5200 - val_loss: 2.2930
# Epoch 95/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1061e-04 - val_accuracy: 0.5200 - val_loss: 2.2970
# Epoch 96/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2179e-04 - val_accuracy: 0.5200 - val_loss: 2.3012
# Epoch 97/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1819e-04 - val_accuracy: 0.5200 - val_loss: 2.3054
# Epoch 98/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.1381e-04 - val_accuracy: 0.5200 - val_loss: 2.3095
# Epoch 99/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.1325e-04 - val_accuracy: 0.5200 - val_loss: 2.3135
# Epoch 100/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1519e-04 - val_accuracy: 0.5200 - val_loss: 2.3174
# Epoch 101/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0607e-04 - val_accuracy: 0.5200 - val_loss: 2.3213
# Epoch 102/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.0163e-04 - val_accuracy: 0.5200 - val_loss: 2.3252
# Epoch 103/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.9626e-05 - val_accuracy: 0.5200 - val_loss: 2.3290
# Epoch 104/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.9643e-05 - val_accuracy: 0.5200 - val_loss: 2.3329
# Epoch 105/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.9034e-05 - val_accuracy: 0.5200 - val_loss: 2.3367
# Epoch 106/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0094e-04 - val_accuracy: 0.5200 - val_loss: 2.3406
# Epoch 107/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 9.5868e-05 - val_accuracy: 0.5200 - val_loss: 2.3444
# Epoch 108/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.7304e-05 - val_accuracy: 0.5200 - val_loss: 2.3481
# Epoch 109/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 9.2332e-05 - val_accuracy: 0.5200 - val_loss: 2.3517
# Epoch 110/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 8.9852e-05 - val_accuracy: 0.5200 - val_loss: 2.3554
# Epoch 111/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.0588e-05 - val_accuracy: 0.5200 - val_loss: 2.3592
# Epoch 112/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 8.6931e-05 - val_accuracy: 0.5200 - val_loss: 2.3630
# Epoch 113/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.5601e-05 - val_accuracy: 0.5200 - val_loss: 2.3668
# Epoch 114/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.2013e-05 - val_accuracy: 0.5200 - val_loss: 2.3705
# Epoch 115/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.2264e-05 - val_accuracy: 0.5200 - val_loss: 2.3742
# Epoch 116/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 8.8095e-05 - val_accuracy: 0.5200 - val_loss: 2.3778
# Epoch 117/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.2370e-05 - val_accuracy: 0.5200 - val_loss: 2.3815
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.2032e-05 - val_accuracy: 0.5200 - val_loss: 2.3849
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.1150e-05 - val_accuracy: 0.5200 - val_loss: 2.3885
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.7014e-05 - val_accuracy: 0.5200 - val_loss: 2.3920
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 7.0394e-05 - val_accuracy: 0.5200 - val_loss: 2.3955
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.4505e-05 - val_accuracy: 0.5200 - val_loss: 2.3990
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 7.5228e-05 - val_accuracy: 0.5200 - val_loss: 2.4025
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 8.1336e-05 - val_accuracy: 0.5200 - val_loss: 2.4061
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.1955e-05 - val_accuracy: 0.5200 - val_loss: 2.4095
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 7.5983e-05 - val_accuracy: 0.5200 - val_loss: 2.4129
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.9095e-05 - val_accuracy: 0.5200 - val_loss: 2.4161
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.9677e-05 - val_accuracy: 0.5200 - val_loss: 2.4193
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.6592e-05 - val_accuracy: 0.5200 - val_loss: 2.4225
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 6.5855e-05 - val_accuracy: 0.5200 - val_loss: 2.4256
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 7.3214e-05 - val_accuracy: 0.5067 - val_loss: 2.4290
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.8834e-05 - val_accuracy: 0.5067 - val_loss: 2.4321
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.2615e-05 - val_accuracy: 0.5067 - val_loss: 2.4351
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.3659e-05 - val_accuracy: 0.5067 - val_loss: 2.4382
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.5605e-05 - val_accuracy: 0.5067 - val_loss: 2.4413
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.9947e-05 - val_accuracy: 0.5067 - val_loss: 2.4444
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.3499e-05 - val_accuracy: 0.5067 - val_loss: 2.4476
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 6.0626e-05 - val_accuracy: 0.5067 - val_loss: 2.4506
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 6.1721e-05 - val_accuracy: 0.5067 - val_loss: 2.4536
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.5464e-05 - val_accuracy: 0.5067 - val_loss: 2.4566
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.7753e-05 - val_accuracy: 0.5067 - val_loss: 2.4596
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.1079e-05 - val_accuracy: 0.5067 - val_loss: 2.4626
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.6213e-05 - val_accuracy: 0.5067 - val_loss: 2.4656
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.2654e-05 - val_accuracy: 0.5067 - val_loss: 2.4686
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.6184e-05 - val_accuracy: 0.5067 - val_loss: 2.4716
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.5375e-05 - val_accuracy: 0.5067 - val_loss: 2.4745
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.5338e-05 - val_accuracy: 0.5067 - val_loss: 2.4775
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.3599e-05 - val_accuracy: 0.5067 - val_loss: 2.4804
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.2976e-05 - val_accuracy: 0.5067 - val_loss: 2.4832
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.2383e-05 - val_accuracy: 0.5067 - val_loss: 2.4860
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 5.2027e-05 - val_accuracy: 0.5067 - val_loss: 2.4888
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 5.4425e-05 - val_accuracy: 0.5067 - val_loss: 2.4915
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.1541e-05 - val_accuracy: 0.5067 - val_loss: 2.4942
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.6479e-05 - val_accuracy: 0.5067 - val_loss: 2.4969
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 5.0308e-05 - val_accuracy: 0.5067 - val_loss: 2.4996
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 5.3570e-05 - val_accuracy: 0.5067 - val_loss: 2.5024
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.4113e-05 - val_accuracy: 0.5067 - val_loss: 2.5051
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.7277e-05 - val_accuracy: 0.5067 - val_loss: 2.5080
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.8047e-05 - val_accuracy: 0.5067 - val_loss: 2.5109
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.3431e-05 - val_accuracy: 0.5067 - val_loss: 2.5136
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 4.7675e-05 - val_accuracy: 0.5067 - val_loss: 2.5163
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 4.5004e-05 - val_accuracy: 0.5067 - val_loss: 2.5190
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 4.8218e-05 - val_accuracy: 0.5067 - val_loss: 2.5218
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 4.6083e-05 - val_accuracy: 0.5067 - val_loss: 2.5245
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.3065e-05 - val_accuracy: 0.5067 - val_loss: 2.5272
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 4.1023e-05 - val_accuracy: 0.5067 - val_loss: 2.5297
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.1618e-05 - val_accuracy: 0.5067 - val_loss: 2.5324
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.0729e-05 - val_accuracy: 0.5067 - val_loss: 2.5350
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 4.0339e-05 - val_accuracy: 0.5067 - val_loss: 2.5376
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 4.1530e-05 - val_accuracy: 0.5067 - val_loss: 2.5402
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.0557e-05 - val_accuracy: 0.5067 - val_loss: 2.5428
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.7298e-05 - val_accuracy: 0.5067 - val_loss: 2.5454
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 3.9018e-05 - val_accuracy: 0.5067 - val_loss: 2.5480
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 4.1278e-05 - val_accuracy: 0.5067 - val_loss: 2.5506
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.9132e-05 - val_accuracy: 0.5067 - val_loss: 2.5532
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.9687e-05 - val_accuracy: 0.5067 - val_loss: 2.5559
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.6200e-05 - val_accuracy: 0.5067 - val_loss: 2.5583
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 3.9036e-05 - val_accuracy: 0.5067 - val_loss: 2.5608
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 3.6571e-05 - val_accuracy: 0.5067 - val_loss: 2.5632
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 3.4262e-05 - val_accuracy: 0.5067 - val_loss: 2.5655
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 3.8109e-05 - val_accuracy: 0.5067 - val_loss: 2.5681
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 3.3761e-05 - val_accuracy: 0.5067 - val_loss: 2.5705
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.4844e-05 - val_accuracy: 0.5067 - val_loss: 2.5730
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.3915e-05 - val_accuracy: 0.5067 - val_loss: 2.5754
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.4682e-05 - val_accuracy: 0.5067 - val_loss: 2.5778
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.4502e-05 - val_accuracy: 0.5067 - val_loss: 2.5802
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.2984e-05 - val_accuracy: 0.5067 - val_loss: 2.5827
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.6960e-05 - val_accuracy: 0.5067 - val_loss: 2.5851
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.4481e-05 - val_accuracy: 0.5067 - val_loss: 2.5875
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.1307e-05 - val_accuracy: 0.5067 - val_loss: 2.5897
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.2805e-05 - val_accuracy: 0.5067 - val_loss: 2.5921
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.3761e-05 - val_accuracy: 0.5067 - val_loss: 2.5944
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.2661e-05 - val_accuracy: 0.5067 - val_loss: 2.5967
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.4788e-05 - val_accuracy: 0.5067 - val_loss: 2.5990
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.9430e-05 - val_accuracy: 0.5067 - val_loss: 2.6013
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.2763e-05 - val_accuracy: 0.5067 - val_loss: 2.6035
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.1327e-05 - val_accuracy: 0.5067 - val_loss: 2.6058
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.1923e-05 - val_accuracy: 0.5067 - val_loss: 2.6081
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.2941e-05 - val_accuracy: 0.5067 - val_loss: 2.6103
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 3.0753e-05 - val_accuracy: 0.5067 - val_loss: 2.6125
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.0878e-05 - val_accuracy: 0.5067 - val_loss: 2.6147
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.9977e-05 - val_accuracy: 0.5067 - val_loss: 2.6168
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 3.0723e-05 - val_accuracy: 0.5067 - val_loss: 2.6189
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.9919e-05 - val_accuracy: 0.5067 - val_loss: 2.6211
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.1295e-05 - val_accuracy: 0.5067 - val_loss: 2.6232
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.8144e-05 - val_accuracy: 0.5067 - val_loss: 2.6254
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.8248e-05 - val_accuracy: 0.5067 - val_loss: 2.6275
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.9179e-05 - val_accuracy: 0.5067 - val_loss: 2.6297
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.8332e-05 - val_accuracy: 0.5067 - val_loss: 2.6318
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.8747e-05 - val_accuracy: 0.5067 - val_loss: 2.6339
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.6596e-05 - val_accuracy: 0.5067 - val_loss: 2.6360
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.5131e-05 - val_accuracy: 0.5067 - val_loss: 2.6382
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.4729e-05 - val_accuracy: 0.5067 - val_loss: 2.6403
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.7096e-05 - val_accuracy: 0.5067 - val_loss: 2.6424
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.7517e-05 - val_accuracy: 0.5067 - val_loss: 2.6446
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.5694e-05 - val_accuracy: 0.5067 - val_loss: 2.6466
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.5327e-05 - val_accuracy: 0.5067 - val_loss: 2.6488
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.4842e-05 - val_accuracy: 0.5067 - val_loss: 2.6508
# Epoch 219/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.4946e-05 - val_accuracy: 0.5067 - val_loss: 2.6529
# Epoch 220/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.6445e-05 - val_accuracy: 0.5067 - val_loss: 2.6550
# Epoch 221/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.6878e-05 - val_accuracy: 0.5067 - val_loss: 2.6571
# Epoch 222/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.3824e-05 - val_accuracy: 0.5067 - val_loss: 2.6590
# Epoch 223/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.5340e-05 - val_accuracy: 0.5067 - val_loss: 2.6611
# Epoch 224/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.3273e-05 - val_accuracy: 0.5067 - val_loss: 2.6630
# Epoch 225/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.3855e-05 - val_accuracy: 0.5067 - val_loss: 2.6651
# Epoch 226/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.3777e-05 - val_accuracy: 0.5067 - val_loss: 2.6671
# Epoch 227/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.4206e-05 - val_accuracy: 0.5067 - val_loss: 2.6691
# Epoch 228/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.1560e-05 - val_accuracy: 0.5067 - val_loss: 2.6710
# Epoch 229/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.4501e-05 - val_accuracy: 0.5067 - val_loss: 2.6730
# Epoch 230/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.1049e-05 - val_accuracy: 0.5067 - val_loss: 2.6750
# Epoch 231/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.1611e-05 - val_accuracy: 0.5067 - val_loss: 2.6770
# Epoch 232/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 2.4120e-05 - val_accuracy: 0.5067 - val_loss: 2.6790
# Epoch 233/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.3554e-05 - val_accuracy: 0.5067 - val_loss: 2.6810
# Epoch 234/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.3236e-05 - val_accuracy: 0.5067 - val_loss: 2.6829
# Epoch 235/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.2650e-05 - val_accuracy: 0.5067 - val_loss: 2.6849
# Epoch 236/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.2016e-05 - val_accuracy: 0.5067 - val_loss: 2.6867
# Epoch 237/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.2498e-05 - val_accuracy: 0.5067 - val_loss: 2.6886
# Epoch 238/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.0615e-05 - val_accuracy: 0.5067 - val_loss: 2.6905
# Epoch 239/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.3079e-05 - val_accuracy: 0.5067 - val_loss: 2.6924
# Epoch 240/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.1641e-05 - val_accuracy: 0.5067 - val_loss: 2.6942
# Epoch 241/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.2583e-05 - val_accuracy: 0.5067 - val_loss: 2.6961
# Epoch 242/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.9738e-05 - val_accuracy: 0.5067 - val_loss: 2.6980
# Epoch 243/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.8819e-05 - val_accuracy: 0.5067 - val_loss: 2.6999
# Epoch 244/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 2.0771e-05 - val_accuracy: 0.5067 - val_loss: 2.7018
# Epoch 245/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.1506e-05 - val_accuracy: 0.5067 - val_loss: 2.7037
# Epoch 246/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 2.2066e-05 - val_accuracy: 0.5067 - val_loss: 2.7056
# Epoch 247/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 2.0834e-05 - val_accuracy: 0.5067 - val_loss: 2.7074
# Epoch 248/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 2.0506e-05 - val_accuracy: 0.5067 - val_loss: 2.7093
# Epoch 249/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.0080e-05 - val_accuracy: 0.5067 - val_loss: 2.7112
# Epoch 250/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.0772e-05 - val_accuracy: 0.5067 - val_loss: 2.7131
# Epoch 251/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.9963e-05 - val_accuracy: 0.5067 - val_loss: 2.7149
# Epoch 252/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.9147e-05 - val_accuracy: 0.5067 - val_loss: 2.7167
# Epoch 253/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.8697e-05 - val_accuracy: 0.5067 - val_loss: 2.7185
# Epoch 254/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.9226e-05 - val_accuracy: 0.5067 - val_loss: 2.7204
# Epoch 255/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.8478e-05 - val_accuracy: 0.5067 - val_loss: 2.7221
# Epoch 256/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.8063e-05 - val_accuracy: 0.5067 - val_loss: 2.7239
# Epoch 257/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 2.0147e-05 - val_accuracy: 0.5067 - val_loss: 2.7257
# Epoch 258/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.9545e-05 - val_accuracy: 0.5067 - val_loss: 2.7275
# Epoch 259/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.8482e-05 - val_accuracy: 0.5067 - val_loss: 2.7292
# Epoch 260/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.8844e-05 - val_accuracy: 0.5067 - val_loss: 2.7310
# Epoch 261/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.7041e-05 - val_accuracy: 0.5067 - val_loss: 2.7327
# Epoch 262/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.8906e-05 - val_accuracy: 0.5067 - val_loss: 2.7344
# Epoch 263/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.8226e-05 - val_accuracy: 0.5067 - val_loss: 2.7361
# Epoch 264/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.7744e-05 - val_accuracy: 0.5067 - val_loss: 2.7379
# Epoch 265/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.7574e-05 - val_accuracy: 0.5067 - val_loss: 2.7397
# Epoch 266/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.7832e-05 - val_accuracy: 0.5067 - val_loss: 2.7414
# Epoch 267/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.7152e-05 - val_accuracy: 0.5067 - val_loss: 2.7431
# Epoch 268/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.8951e-05 - val_accuracy: 0.5067 - val_loss: 2.7448
# Epoch 269/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.7381e-05 - val_accuracy: 0.5067 - val_loss: 2.7465
# Epoch 270/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.6203e-05 - val_accuracy: 0.5067 - val_loss: 2.7482
# Epoch 271/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.6545e-05 - val_accuracy: 0.5067 - val_loss: 2.7499
# Epoch 272/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.6923e-05 - val_accuracy: 0.5067 - val_loss: 2.7516
# Epoch 273/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.6116e-05 - val_accuracy: 0.5067 - val_loss: 2.7533
# Epoch 274/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.7327e-05 - val_accuracy: 0.5067 - val_loss: 2.7551
# Epoch 275/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.7748e-05 - val_accuracy: 0.5067 - val_loss: 2.7568
# Epoch 276/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.6770e-05 - val_accuracy: 0.5067 - val_loss: 2.7585
# Epoch 277/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.5558e-05 - val_accuracy: 0.5067 - val_loss: 2.7602
# Epoch 278/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.6112e-05 - val_accuracy: 0.5067 - val_loss: 2.7619
# Epoch 279/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.6309e-05 - val_accuracy: 0.5067 - val_loss: 2.7636
# Epoch 280/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.6928e-05 - val_accuracy: 0.5067 - val_loss: 2.7653
# Epoch 281/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.6421e-05 - val_accuracy: 0.5067 - val_loss: 2.7670
# Epoch 282/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.4559e-05 - val_accuracy: 0.5067 - val_loss: 2.7686
# Epoch 283/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.5523e-05 - val_accuracy: 0.5067 - val_loss: 2.7703
# Epoch 284/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4560e-05 - val_accuracy: 0.5067 - val_loss: 2.7719
# Epoch 285/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.5119e-05 - val_accuracy: 0.5067 - val_loss: 2.7735
# Epoch 286/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.5468e-05 - val_accuracy: 0.5067 - val_loss: 2.7751
# Epoch 287/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.5403e-05 - val_accuracy: 0.5067 - val_loss: 2.7767
# Epoch 288/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.4899e-05 - val_accuracy: 0.5067 - val_loss: 2.7783
# Epoch 289/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.6435e-05 - val_accuracy: 0.5067 - val_loss: 2.7799
# Epoch 290/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.5940e-05 - val_accuracy: 0.5067 - val_loss: 2.7814
# Epoch 291/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4878e-05 - val_accuracy: 0.5067 - val_loss: 2.7830
# Epoch 292/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.5630e-05 - val_accuracy: 0.5067 - val_loss: 2.7845
# Epoch 293/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.5000e-05 - val_accuracy: 0.5067 - val_loss: 2.7861
# Epoch 294/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.3708e-05 - val_accuracy: 0.5067 - val_loss: 2.7876
# Epoch 295/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.4250e-05 - val_accuracy: 0.5067 - val_loss: 2.7892
# Epoch 296/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.4320e-05 - val_accuracy: 0.5067 - val_loss: 2.7907
# Epoch 297/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4898e-05 - val_accuracy: 0.5067 - val_loss: 2.7923
# Epoch 298/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4175e-05 - val_accuracy: 0.5067 - val_loss: 2.7939
# Epoch 299/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.4784e-05 - val_accuracy: 0.5067 - val_loss: 2.7955
# Epoch 300/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3969e-05 - val_accuracy: 0.5067 - val_loss: 2.7970
# Epoch 301/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.3755e-05 - val_accuracy: 0.5067 - val_loss: 2.7986
# Epoch 302/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3021e-05 - val_accuracy: 0.5067 - val_loss: 2.8001
# Epoch 303/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.3489e-05 - val_accuracy: 0.5067 - val_loss: 2.8017
# Epoch 304/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.3441e-05 - val_accuracy: 0.5067 - val_loss: 2.8032
# Epoch 305/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4161e-05 - val_accuracy: 0.5067 - val_loss: 2.8047
# Epoch 306/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.2988e-05 - val_accuracy: 0.5067 - val_loss: 2.8062
# Epoch 307/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3533e-05 - val_accuracy: 0.5067 - val_loss: 2.8077
# Epoch 308/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.3284e-05 - val_accuracy: 0.5067 - val_loss: 2.8092
# Epoch 309/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1982e-05 - val_accuracy: 0.5067 - val_loss: 2.8107
# Epoch 310/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.3537e-05 - val_accuracy: 0.5067 - val_loss: 2.8122
# Epoch 311/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2633e-05 - val_accuracy: 0.5067 - val_loss: 2.8137
# Epoch 312/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3461e-05 - val_accuracy: 0.5067 - val_loss: 2.8152
# Epoch 313/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2392e-05 - val_accuracy: 0.5067 - val_loss: 2.8167
# Epoch 314/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2722e-05 - val_accuracy: 0.5067 - val_loss: 2.8182
# Epoch 315/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.2721e-05 - val_accuracy: 0.5067 - val_loss: 2.8197
# Epoch 316/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.3129e-05 - val_accuracy: 0.5067 - val_loss: 2.8212
# Epoch 317/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3337e-05 - val_accuracy: 0.5067 - val_loss: 2.8226
# Epoch 318/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.3266e-05 - val_accuracy: 0.5067 - val_loss: 2.8241
# Epoch 319/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2908e-05 - val_accuracy: 0.5067 - val_loss: 2.8256
# Epoch 320/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2839e-05 - val_accuracy: 0.5067 - val_loss: 2.8270
# Epoch 321/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1831e-05 - val_accuracy: 0.5067 - val_loss: 2.8284
# Epoch 322/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2064e-05 - val_accuracy: 0.5067 - val_loss: 2.8299
# Epoch 323/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1468e-05 - val_accuracy: 0.5067 - val_loss: 2.8314
# Epoch 324/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1966e-05 - val_accuracy: 0.5067 - val_loss: 2.8329
# Epoch 325/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1798e-05 - val_accuracy: 0.5067 - val_loss: 2.8344
# Epoch 326/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.2727e-05 - val_accuracy: 0.5067 - val_loss: 2.8358
# Epoch 327/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1639e-05 - val_accuracy: 0.5067 - val_loss: 2.8373
# Epoch 328/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.1867e-05 - val_accuracy: 0.5067 - val_loss: 2.8388
# Epoch 329/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.0959e-05 - val_accuracy: 0.5067 - val_loss: 2.8402
# Epoch 330/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1001e-05 - val_accuracy: 0.5067 - val_loss: 2.8417
# Epoch 331/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.1452e-05 - val_accuracy: 0.5067 - val_loss: 2.8432
# Epoch 332/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.1902e-05 - val_accuracy: 0.5067 - val_loss: 2.8446
# Epoch 333/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0670e-05 - val_accuracy: 0.5067 - val_loss: 2.8461
# Epoch 334/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1963e-05 - val_accuracy: 0.5067 - val_loss: 2.8475
# Epoch 335/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1885e-05 - val_accuracy: 0.5067 - val_loss: 2.8489
# Epoch 336/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.1173e-05 - val_accuracy: 0.5067 - val_loss: 2.8503
# Epoch 337/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1380e-05 - val_accuracy: 0.5067 - val_loss: 2.8518
# Epoch 338/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.1612e-05 - val_accuracy: 0.5067 - val_loss: 2.8532
# Epoch 339/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 1.0800e-05 - val_accuracy: 0.5067 - val_loss: 2.8546
# Epoch 340/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1227e-05 - val_accuracy: 0.5067 - val_loss: 2.8560
# Epoch 341/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0590e-05 - val_accuracy: 0.5067 - val_loss: 2.8574
# Epoch 342/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1176e-05 - val_accuracy: 0.5067 - val_loss: 2.8588
# Epoch 343/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0475e-05 - val_accuracy: 0.5067 - val_loss: 2.8603
# Epoch 344/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.0517e-05 - val_accuracy: 0.5067 - val_loss: 2.8617
# Epoch 345/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.8870e-06 - val_accuracy: 0.5067 - val_loss: 2.8631
# Epoch 346/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0579e-05 - val_accuracy: 0.5067 - val_loss: 2.8645
# Epoch 347/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.0796e-05 - val_accuracy: 0.5067 - val_loss: 2.8660
# Epoch 348/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 9.9158e-06 - val_accuracy: 0.5067 - val_loss: 2.8673
# Epoch 349/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1482e-05 - val_accuracy: 0.5067 - val_loss: 2.8687
# Epoch 350/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 1.1140e-05 - val_accuracy: 0.5067 - val_loss: 2.8701
# Epoch 351/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0437e-05 - val_accuracy: 0.5067 - val_loss: 2.8714
# Epoch 352/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0579e-05 - val_accuracy: 0.5067 - val_loss: 2.8727
# Epoch 353/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0873e-05 - val_accuracy: 0.5067 - val_loss: 2.8741
# Epoch 354/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.7886e-06 - val_accuracy: 0.5067 - val_loss: 2.8754
# Epoch 355/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.1272e-06 - val_accuracy: 0.5067 - val_loss: 2.8768
# Epoch 356/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.7076e-06 - val_accuracy: 0.5067 - val_loss: 2.8783
# Epoch 357/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0398e-05 - val_accuracy: 0.5067 - val_loss: 2.8797
# Epoch 358/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0676e-05 - val_accuracy: 0.5067 - val_loss: 2.8810
# Epoch 359/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.2121e-06 - val_accuracy: 0.5067 - val_loss: 2.8824
# Epoch 360/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.9482e-06 - val_accuracy: 0.5067 - val_loss: 2.8837
# Epoch 361/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.5931e-06 - val_accuracy: 0.5067 - val_loss: 2.8850
# Epoch 362/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 8.3954e-06 - val_accuracy: 0.5067 - val_loss: 2.8863
# Epoch 363/1000
# ...
# Epoch 881/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 1.2018e-06 - val_accuracy: 0.5200 - val_loss: 3.3730
# Epoch 882/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1657e-06 - val_accuracy: 0.5200 - val_loss: 3.3737
# Epoch 883/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1649e-06 - val_accuracy: 0.5200 - val_loss: 3.3744
# Epoch 884/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.3432e-06 - val_accuracy: 0.5200 - val_loss: 3.3751
# Epoch 885/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.2778e-06 - val_accuracy: 0.5200 - val_loss: 3.3759
# Epoch 886/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2346e-06 - val_accuracy: 0.5200 - val_loss: 3.3766
# Epoch 887/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2150e-06 - val_accuracy: 0.5200 - val_loss: 3.3774
# Epoch 888/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.2779e-06 - val_accuracy: 0.5200 - val_loss: 3.3781
# Epoch 889/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.3140e-06 - val_accuracy: 0.5200 - val_loss: 3.3788
# Epoch 890/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2428e-06 - val_accuracy: 0.5200 - val_loss: 3.3795
# Epoch 891/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.2265e-06 - val_accuracy: 0.5200 - val_loss: 3.3802
# Epoch 892/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.2136e-06 - val_accuracy: 0.5200 - val_loss: 3.3809
# Epoch 893/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2526e-06 - val_accuracy: 0.5200 - val_loss: 3.3816
# Epoch 894/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1829e-06 - val_accuracy: 0.5200 - val_loss: 3.3823
# Epoch 895/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.2621e-06 - val_accuracy: 0.5200 - val_loss: 3.3831
# Epoch 896/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1880e-06 - val_accuracy: 0.5200 - val_loss: 3.3838
# Epoch 897/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2321e-06 - val_accuracy: 0.5200 - val_loss: 3.3845
# Epoch 898/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2440e-06 - val_accuracy: 0.5200 - val_loss: 3.3853
# Epoch 899/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1885e-06 - val_accuracy: 0.5200 - val_loss: 3.3860
# Epoch 900/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2035e-06 - val_accuracy: 0.5200 - val_loss: 3.3867
# Epoch 901/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0703e-06 - val_accuracy: 0.5200 - val_loss: 3.3874
# Epoch 902/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1894e-06 - val_accuracy: 0.5200 - val_loss: 3.3881
# Epoch 903/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1403e-06 - val_accuracy: 0.5200 - val_loss: 3.3889
# Epoch 904/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1879e-06 - val_accuracy: 0.5200 - val_loss: 3.3896
# Epoch 905/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1403e-06 - val_accuracy: 0.5200 - val_loss: 3.3903
# Epoch 906/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2033e-06 - val_accuracy: 0.5200 - val_loss: 3.3911
# Epoch 907/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1453e-06 - val_accuracy: 0.5200 - val_loss: 3.3918
# Epoch 908/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1865e-06 - val_accuracy: 0.5200 - val_loss: 3.3926
# Epoch 909/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1608e-06 - val_accuracy: 0.5200 - val_loss: 3.3933
# Epoch 910/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1290e-06 - val_accuracy: 0.5200 - val_loss: 3.3940
# Epoch 911/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0896e-06 - val_accuracy: 0.5200 - val_loss: 3.3947
# Epoch 912/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0984e-06 - val_accuracy: 0.5200 - val_loss: 3.3954
# Epoch 913/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1373e-06 - val_accuracy: 0.5200 - val_loss: 3.3961
# Epoch 914/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1706e-06 - val_accuracy: 0.5200 - val_loss: 3.3969
# Epoch 915/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0844e-06 - val_accuracy: 0.5200 - val_loss: 3.3976
# Epoch 916/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.1094e-06 - val_accuracy: 0.5200 - val_loss: 3.3983
# Epoch 917/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1779e-06 - val_accuracy: 0.5200 - val_loss: 3.3990
# Epoch 918/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0772e-06 - val_accuracy: 0.5200 - val_loss: 3.3997
# Epoch 919/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1678e-06 - val_accuracy: 0.5200 - val_loss: 3.4004
# Epoch 920/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.0941e-06 - val_accuracy: 0.5200 - val_loss: 3.4011
# Epoch 921/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0653e-06 - val_accuracy: 0.5200 - val_loss: 3.4018
# Epoch 922/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0651e-06 - val_accuracy: 0.5200 - val_loss: 3.4025
# Epoch 923/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1052e-06 - val_accuracy: 0.5200 - val_loss: 3.4032
# Epoch 924/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.1543e-06 - val_accuracy: 0.5200 - val_loss: 3.4039
# Epoch 925/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.0451e-06 - val_accuracy: 0.5200 - val_loss: 3.4046
# Epoch 926/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1953e-06 - val_accuracy: 0.5200 - val_loss: 3.4054
# Epoch 927/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0492e-06 - val_accuracy: 0.5200 - val_loss: 3.4061
# Epoch 928/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0891e-06 - val_accuracy: 0.5200 - val_loss: 3.4068
# Epoch 929/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.5215e-07 - val_accuracy: 0.5200 - val_loss: 3.4075
# Epoch 930/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.1333e-06 - val_accuracy: 0.5200 - val_loss: 3.4082
# Epoch 931/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0814e-06 - val_accuracy: 0.5200 - val_loss: 3.4090
# Epoch 932/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.1528e-06 - val_accuracy: 0.5200 - val_loss: 3.4097
# Epoch 933/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0907e-06 - val_accuracy: 0.5200 - val_loss: 3.4104
# Epoch 934/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0250e-06 - val_accuracy: 0.5200 - val_loss: 3.4111
# Epoch 935/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0184e-06 - val_accuracy: 0.5200 - val_loss: 3.4118
# Epoch 936/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.1632e-06 - val_accuracy: 0.5200 - val_loss: 3.4126
# Epoch 937/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0531e-06 - val_accuracy: 0.5200 - val_loss: 3.4133
# Epoch 938/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1082e-06 - val_accuracy: 0.5200 - val_loss: 3.4140
# Epoch 939/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0001e-06 - val_accuracy: 0.5200 - val_loss: 3.4146
# Epoch 940/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.6307e-07 - val_accuracy: 0.5200 - val_loss: 3.4154
# Epoch 941/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.4083e-07 - val_accuracy: 0.5200 - val_loss: 3.4161
# Epoch 942/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.7751e-07 - val_accuracy: 0.5200 - val_loss: 3.4168
# Epoch 943/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0438e-06 - val_accuracy: 0.5200 - val_loss: 3.4175
# Epoch 944/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.0198e-06 - val_accuracy: 0.5200 - val_loss: 3.4183
# Epoch 945/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.8491e-07 - val_accuracy: 0.5200 - val_loss: 3.4190
# Epoch 946/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0798e-06 - val_accuracy: 0.5200 - val_loss: 3.4197
# Epoch 947/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.9045e-07 - val_accuracy: 0.5200 - val_loss: 3.4204
# Epoch 948/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.9327e-07 - val_accuracy: 0.5200 - val_loss: 3.4211
# Epoch 949/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0490e-06 - val_accuracy: 0.5200 - val_loss: 3.4218
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0424e-06 - val_accuracy: 0.5200 - val_loss: 3.4225
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0143e-06 - val_accuracy: 0.5200 - val_loss: 3.4232
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0388e-06 - val_accuracy: 0.5200 - val_loss: 3.4240
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.1604e-06 - val_accuracy: 0.5200 - val_loss: 3.4247
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.0397e-06 - val_accuracy: 0.5200 - val_loss: 3.4254
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.7294e-07 - val_accuracy: 0.5200 - val_loss: 3.4260
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 9.9178e-07 - val_accuracy: 0.5200 - val_loss: 3.4268
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.9776e-07 - val_accuracy: 0.5200 - val_loss: 3.4275
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.0176e-06 - val_accuracy: 0.5200 - val_loss: 3.4282
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0043e-06 - val_accuracy: 0.5200 - val_loss: 3.4289
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.0145e-06 - val_accuracy: 0.5200 - val_loss: 3.4295
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 9.5823e-07 - val_accuracy: 0.5200 - val_loss: 3.4302
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0258e-06 - val_accuracy: 0.5200 - val_loss: 3.4309
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.9738e-07 - val_accuracy: 0.5200 - val_loss: 3.4316
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 9.7432e-07 - val_accuracy: 0.5200 - val_loss: 3.4323
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0092e-06 - val_accuracy: 0.5200 - val_loss: 3.4330
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.1917e-07 - val_accuracy: 0.5200 - val_loss: 3.4336
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.7975e-07 - val_accuracy: 0.5200 - val_loss: 3.4343
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.0753e-07 - val_accuracy: 0.5200 - val_loss: 3.4350
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0372e-06 - val_accuracy: 0.5200 - val_loss: 3.4357
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.1971e-07 - val_accuracy: 0.5200 - val_loss: 3.4364
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0013e-06 - val_accuracy: 0.5200 - val_loss: 3.4371
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.4143e-07 - val_accuracy: 0.5200 - val_loss: 3.4378
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0184e-06 - val_accuracy: 0.5200 - val_loss: 3.4385
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.4403e-07 - val_accuracy: 0.5200 - val_loss: 3.4392
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 9.7475e-07 - val_accuracy: 0.5200 - val_loss: 3.4399
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.0438e-07 - val_accuracy: 0.5200 - val_loss: 3.4405
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 9.5066e-07 - val_accuracy: 0.5200 - val_loss: 3.4412
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.1556e-07 - val_accuracy: 0.5200 - val_loss: 3.4419
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.4131e-07 - val_accuracy: 0.5200 - val_loss: 3.4426
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.5286e-07 - val_accuracy: 0.5200 - val_loss: 3.4433
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.6696e-07 - val_accuracy: 0.5200 - val_loss: 3.4439
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.3090e-07 - val_accuracy: 0.5200 - val_loss: 3.4446
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.2980e-07 - val_accuracy: 0.5200 - val_loss: 3.4453
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 1.0302e-06 - val_accuracy: 0.5200 - val_loss: 3.4460
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.2114e-07 - val_accuracy: 0.5200 - val_loss: 3.4467
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.4244e-07 - val_accuracy: 0.5200 - val_loss: 3.4474
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.2158e-07 - val_accuracy: 0.5200 - val_loss: 3.4481
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 8.4202e-07 - val_accuracy: 0.5200 - val_loss: 3.4488
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.5811e-07 - val_accuracy: 0.5200 - val_loss: 3.4495
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.2239e-07 - val_accuracy: 0.5200 - val_loss: 3.4502
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 9.4313e-07 - val_accuracy: 0.5200 - val_loss: 3.4508
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.3424e-07 - val_accuracy: 0.5200 - val_loss: 3.4515
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 9.1116e-07 - val_accuracy: 0.5200 - val_loss: 3.4522
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.5905e-07 - val_accuracy: 0.5200 - val_loss: 3.4528
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 8.9733e-07 - val_accuracy: 0.5200 - val_loss: 3.4535
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.8657e-07 - val_accuracy: 0.5200 - val_loss: 3.4542
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.2724e-07 - val_accuracy: 0.5200 - val_loss: 3.4548
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 8.7348e-07 - val_accuracy: 0.5200 - val_loss: 3.4555
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.3319e-07 - val_accuracy: 0.5200 - val_loss: 3.4562
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 9.1821e-07 - val_accuracy: 0.5200 - val_loss: 3.4569

# %%
# Run this cell without changes

def plot_loss_and_accuracy(results, final=False):
    
    if final:
        val_label="test"
    else:
        val_label="validation"

    # Extracting metrics from model fitting
    train_loss = results.history['loss']
    val_loss = results.history['val_loss']
    train_accuracy = results.history['accuracy']
    val_accuracy = results.history['val_accuracy']

    # Setting up plots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    # Plotting loss info
    ax1.set_title("Loss")
    sns.lineplot(x=results.epoch, y=train_loss, ax=ax1, label="train")
    sns.lineplot(x=results.epoch, y=val_loss, ax=ax1, label=val_label)
    ax1.legend()

    # Plotting accuracy info
    ax2.set_title("Accuracy")
    sns.lineplot(x=results.epoch, y=train_accuracy, ax=ax2, label="train")
    sns.lineplot(x=results.epoch, y=val_accuracy, ax=ax2, label=val_label)
    ax2.legend()
    
plot_loss_and_accuracy(dense_model_results)

# %% [markdown]
# ## 5) Modify the Code Below to Use Regularization
#
#
# The model appears to be overfitting. To deal with this overfitting, modify the code below to include regularization in the model. You can add L1, L2, both L1 and L2, or dropout regularization.
#
# Hint: these might be helpful
#
#  - [`Dense` layer documentation](https://keras.io/api/layers/core_layers/dense/)
#  - [`regularizers` documentation](https://keras.io/regularizers/)
#
# (`EarlyStopping` is a type of regularization that is not applicable to this problem framing, since it's a callback and not a layer.)

# %%
# Complete the following code

def build_model_with_regularization(n_input, n_output, activation, loss):
    """
    Creates and compiles a tf.keras Sequential model with two hidden layers
    This time regularization has been added
    """
    # create classifier
    classifier = Sequential(name="regularized")

    # add input layer
    classifier.add(Dense(units=64, input_shape=(n_input,)))

    # add hidden layers
    classifier.add(Dense(units=64, kernel_regularizer=regularizers.l2(0.01)))
    classifier.add(Dropout(0.3))

    # add output layer
    classifier.add(Dense(units=n_output, activation=activation))


    classifier.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    return classifier

model_with_regularization = build_model_with_regularization(
    num_input_nodes, num_output_nodes, activation_function, loss
)
model_with_regularization.summary()
# Out:
# C:\Users\anjacobs\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "regularized"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │        19,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,489 (91.75 KB)
#  Trainable params: 23,489 (91.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Run the code below without change

# Testing function to build model
assert type(model_with_regularization) == Sequential

def check_regularization(model):
    regularization_count = 0
    for layer in model.get_config()['layers']:
        
        # Checking if kernel regularizer was specified
        if 'kernel_regularizer' in layer['config']:
            if layer['config'].get('kernel_regularizer'):
                regularization_count += 1
                
        # Checking if layer is dropout layer
        if layer["class_name"] == "Dropout":
            regularization_count += 1
            
    return regularization_count > 0
    
score = .3

if check_regularization(model_with_regularization):
    score += .7
    
score
# Out:
# 1.0

# %% [markdown]
# Now we'll evaluate the new model on the training set as well:

# %%
# Run this cell without changes

# Fit the model to the training data, using a subset of the
# training data as validation data
reg_model_results = model_with_regularization.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=0,
    validation_split=0.4,
    shuffle=False
)

plot_loss_and_accuracy(reg_model_results)

# %% [markdown]
# (Whether or not your regularization made a difference will partially depend on how strong of regularization you applied, as well as some random elements of your current TensorFlow configuration.)
#
# Now we evaluate both models on the holdout set:

# %%
# Run this cell without changes

final_dense_model_results = dense_model.fit(
    x=X_train,
    y=y_train,
    batch_size=None,
    epochs=20,
    verbose=0,
    validation_data=(X_test, y_test),
    shuffle=False
)

plot_loss_and_accuracy(final_dense_model_results, final=True)

# %% [markdown]
# Plot the loss and accuracy your final regularized model.

# %%
# Replace None, as necessary

final_reg_model_results = model_with_regularization.fit(
    x=X_train,
    y=y_train,
    batch_size=0,
    epochs=20,
    verbose=True,
    validation_data=(X_test, y_test),
    shuffle=False
)

plot_loss_and_accuracy(final_reg_model_results, final=True)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9243 - loss: 0.6843 - val_accuracy: 0.6032 - val_loss: 1.4195
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9444 - loss: 0.5890 - val_accuracy: 0.6349 - val_loss: 1.3008
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9732 - loss: 0.5158 - val_accuracy: 0.6825 - val_loss: 1.2091
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9886 - loss: 0.4808 - val_accuracy: 0.6667 - val_loss: 1.1591
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9936 - loss: 0.4773 - val_accuracy: 0.6825 - val_loss: 1.1412
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9833 - loss: 0.4840 - val_accuracy: 0.6667 - val_loss: 1.1487
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.4480 - val_accuracy: 0.6508 - val_loss: 1.1632
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9965 - loss: 0.4363 - val_accuracy: 0.6667 - val_loss: 1.1805
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.4145 - val_accuracy: 0.6825 - val_loss: 1.2009
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3942 - val_accuracy: 0.6508 - val_loss: 1.2187
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3759 - val_accuracy: 0.6667 - val_loss: 1.2336
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.3684 - val_accuracy: 0.6667 - val_loss: 1.2472
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.3566 - val_accuracy: 0.6825 - val_loss: 1.2528
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.3453 - val_accuracy: 0.6825 - val_loss: 1.2570
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.3367 - val_accuracy: 0.6825 - val_loss: 1.2592
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.3287 - val_accuracy: 0.6825 - val_loss: 1.2599
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.3199 - val_accuracy: 0.6825 - val_loss: 1.2633
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.3084 - val_accuracy: 0.6825 - val_loss: 1.2643
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.3067 - val_accuracy: 0.6825 - val_loss: 1.2676
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.2943 - val_accuracy: 0.6825 - val_loss: 1.2680
